# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranav-Gehlot/environmentalimpact/blob/main/ideologicalassessment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyngrok


import numpy as np
import matplotlib.pyplot as plt

environ=0
foreign=0
economic=0
social=0

def socialPolicy(inp):
 global social
 if (inp == "Strongly agree"):
   social+=2
 elif inp == "strongly disagree":
  social-=2
 elif inp=="neutral":
  social+=0
 elif inp== "agree":
  social+=1
 else:
  social-=1

def economicPolicy(inp):
 global economic
 if (inp == "Strongly agree"):
   economic+=2
 elif (inp == "Strongly disagree"):
    economic-=2
 elif inp=="neutral":
  economic+=0
 elif inp== "agree":
  economic+=1
 else:
  economic-=1

def foreignPolicy(inp):
 global foreign
 if inp == "Strongly agree":
   foreign+=2
 elif inp == "Strongly disagree":
  foreign-=2
 elif inp=="neutral":
   foreign+=0
 elif inp== "agree":
  foreign+=1
 else:
  foreign-=1

def environmentalPolicy(inp):
 global environ
 if inp == "Strongly agree":
      environ+=2
 elif (inp == "Strongly disagree"):
   environ-=2
 elif inp== "neutral":
  environ+=0
 elif inp== "agree":
  environ+=1
 elif inp== "disagree":
  environ-=1

def agreeOrDisagree(inp):
  score=0
  if inp == "Strongly agree":
    print("You strongly agree. On to the next question.")
    score+=2
  elif inp == "Strongly disagree":
    print("You strongly disagree. On to the next question")
    score-=2
  elif inp=="neutral":
   print("You are neutral. Next question")
  elif inp== "agree":
   print("You agree. Next question")
   score+=1
  elif inp== "disagree":
   print("You disagree. Next question")
   score-=1
  else:
   print("You must pick one")


def go():

 print("There will be questions assessing your political views. It is important you ask them to the best of your ability. The first section will be Environmental Policy.")
 print("Choose strongly agree, agree, neutral, disagree, or strongly disagree for the following questions")
 print("Your friend lives in a town that holds the headquarters for a coal company, and Country A’s environmental authority is attempting to regulate the carbon dioxide emissions from the company’s power plants. Country A’s government has the authority to do this. Do you strongly agree: authoritarian left [desire for strong authority combined with left-wing values like preventing climate change] OR Do you Strongly disagree: libertarian right [agents may use whatever resources they want] Just type strongly agree or strongly disagree")
 inp=input()
 agreeOrDisagree(inp)
 environmentalPolicy(inp)

print("Your neighbor wants to build a house on land that he owns. When he begins construction, he is told that this is not allowed because the land contains a wetland that is protected by federal law. He should not be allowed to build the house. Strongly agree: libertarian right [natural resources are unprotected]")
print("Strongly disagree: authoritarian left[(desire for strong authority combined with left-wing values like protection of natural resources]")
inp=input()
agreeOrDisagree(inp)
environmentalPolicy(inp)

print("A company has just been granted a permit by the federal government to discharge excess wastewater into a specific lake. The federal government is allowed to grant such a permit.")
print("Strongly agree: authoritarian right (acceptance of strong authority to enforce right-wing values like the limited role of human activity in climate change")
print("Strongly disagree: libertarian left (desire for less government power, natural resources are protected")
inp=input()
agreeOrDisagree(inp)
environmentalPolicy(inp)


print("Your friend works for a company that arranged for the disposal of hazardous waste on a nearby piece of land, and the federal government conducted a complete cleanup of the area. Your friend’s company should be held responsible for the costs of the cleanup.")
print("Strongly agree: libertarian left (people who appropriate natural resources make payments to others")
print("Strongly disagree: libertarian right (entities can do whatever they please with natural resources)")
inp=input()
agreeOrDisagree(inp)
environmentalPolicy(inp)

print("The city you live in would like to use a nearby pond as a landfill, but the federal government declares this a violation of the law. The federal government has the authority to regulate the pond.")
print("Strongly agree: authoritarian left [desire for strong authority to enforce left-wing values like addressing climate change]")
print("Strongly disagree: libertarian right [companies should be able to do however they please concerning natural resources]")
inp=input()
agreeOrDisagree(inp)
environmentalPolicy(inp)

print("A company cut down a tree, which then fell and injured an endangered animal. The company should be held responsible for harming the animal.")
print("Strongly agree: authoritarian left [protection of animals via government regulations]")
print("Strongly disagree: libertarian right [freedom to treat natural resources however you please]")
inp=input()
agreeOrDisagree(inp)
environmentalPolicy(inp)

print("Company No. 1 is being fined for polluting a nearby lake, but Company No. 1 argues that Company No. 2 also contributed to the pollution. Both companies should be forced to pay the fine.")
print("Strongly agree: libertarian left [pay reparations for negatively impacting natural resources]")
print("Strongly disagree: libertarian right [as little punishment as possible for entities that abuse natural resources]")
inp=input()
agreeOrDisagree(inp)
environmentalPolicy(inp)

print("A fossil fuel refinery in your town is small enough that it is exempt from the government’s new fossil fuel tax. The refinery should NOT receive this exemption.")
print("Strongly agree: libertarian right [should be able to use natural resources in any manner]")
print("Strongly disagree: authoritarian left [government should enforce protection of the environment]")
inp=input()
agreeOrDisagree(inp)
environmentalPolicy(inp)

print("Some of the houses in your town have been damaged by the day-to-day operations of a company working in the area. The owners of the houses should receive financial compensation for the damages.")
print("Strongly agree: libertarian left [make payments to others for damage of natural resources]")
print("Strongly disagree: libertarian right [company may appropriate natural resources and the environment however it chooses]")
inp=input()
agreeOrDisagree(inp)
economicPolicy(inp)

print("The federal government is trying to phase out gasoline engines, an action which would be better for the environment but more expensive for consumers. The federal government should be trying to phase out these engines.")
print("Strongly agree: authoritarian left ([ng authority to protect left-wing values such as preventing climate change]")
print("Strongly disagree: libertarian right [emphasis on a free market economy, less focus on addressing climate change]")
inp=input()
agreeOrDisagree(inp)
economicPolicy(inp)

print("A queer couple wants to be married in a church, but the church expresses that their belief does not permit homosexual marriage. The church should have a right to deny them")
print("Strongly Agree: Libertarian right")
print("Strongly Disagree: Authoritarian left")
inp=input()
agreeOrDisagree(inp)
socialPolicy(inp)

print("An individual refused to stay at a homeless shelter. They should be able to encamp and sleep at public spaces such as sidewalks or parks.")
print("Agree: Libertarian left or Disagree: Authoritarian right")
inp=input()
agreeOrDisagree(inp)
socialPolicy(inp)

print("A man has a family who has been associated with a terrorist group although the man himself has no known connection. The government should allow this man to enter Country A without his status being confirmed")
print("Agree: Libertarian left or Disagree: Authoritarian right")
inp=input()
agreeOrDisagree(inp)
socialPolicy(inp)

print("Under no extenuating circumstances, a woman became pregnant. She did not use contraceptives, and is able to economically support the pregnancy. She has a right to abort the baby")
print(" Agree: Authoritarian right or Disagree: Libertarian left")
inp=input()
agreeOrDisagree(inp)
socialPolicy(inp)

print("Gender identity should be added to anti-discrimination laws along with race and gender.")
print("Agree: Authoritarian left or Disagree: Libertarian right")
inp=input()
agreeOrDisagree(inp)
socialPolicy(inp)

print("Athlete A has recently changed their gender identity from male to female. She has the same bone structure as males, but has been taking female hormones. She should be allowed to compete in the female category for her sport")
print(" Agree: Authoritarian right or Disagree: Libertarian left")
inp=input()
agreeOrDisagree(inp)
socialPolicy(inp)

print("Person A self-identifies as male but is biologically female. Person A should be allowed to use gender specific spaces before surgery or hormones such as locker rooms and bathrooms.")
print("Agree, Disagree, Strongly agree, strongly disagree, neutral")
inp=input()
agreeOrDisagree(inp)
socialPolicy(inp)

print("Adult A has said a speech that shamed Hispanics with racial biases on a public rally. Adult A’s speech should be punished.")
print("Agree: Libertarian right or Disagree: Authoritarian left")
inp=input()
agreeOrDisagree(inp)
socialPolicy(inp)

print("In recent years, the distribution of religion regarding our population has shifted greatly from a dominantly Christian state to a more diverse one. Following this pattern, the government should adjust to such a population and support a separation of church and state by removing references to God in a pledge of allegiance, federal buildings, and our currency.")
print("Agree: Libertarian left or Disagree: authoritarian right")
inp=input()
agreeOrDisagree(inp)
socialPolicy(inp)

print("Couple B immigrated to the United States in search of better job opportunities and economic status but their immigration was undocumented. They have a child in United States territory. The child should be granted citizenship")
print("Agree: Liberal or Disagree: Conservative")
inp=input()
agreeOrDisagree(inp)
socialPolicy(inp)

print("Immigrant A has immigrated to the United States without documentation. They have completed their highschool education and are pursuing college in an in-state public college. They should be offered in-state tuition rates at their college.")
print("Agree: Liberal OR Disagree: Conservative")
inp=input()
agreeOrDisagree(inp)
socialPolicy(inp)

print("The government should require people to be vaccinated for diseases.")
print("Agree: Authoritarian left OR Disagree: Libertarian right")
inp=input()
agreeOrDisagree(inp)
socialPolicy(inp)

print("Country A should immediately speak out against foreign dictatorships that engage in human rights abuses, and issue embargoes and tariffs on these nations")
print("Agree: Liberal (Globalist) or Disagree: Conservative (Isolationist)")
inp=input()
agreeOrDisagree(inp)
foreignPolicy(inp)

print("Country A  should send in military force to take over dictatorships and re-establish democracy in nations that do not have functioning democratic institutions")
print("Agree: Liberal (Globalist) or Disagree: Conservative (Isolationist)")
inp=input()
agreeOrDisagree(inp)
foreignPolicy(inp)

print("Country A should have no interest in the internal affairs of foreign nations, and as long as an abusive dictatorship does not threaten the security of other allies, no action should be taken against them")
print("Agree: Conservative (Isolationist)  or Disagree: Liberal (Globalist)")
inp=input()
agreeOrDisagree(inp)
foreignPolicy(inp)

print("Country A, a developed country, should focus on bringing in as many refugees as possible from nations where human rights abuses take place, and provide aid to those who want to flee from the dictatorship")
print("Agree: Liberal (Globalist) or Disagree: Conservative (Isolationist)")
inp=input()
agreeOrDisagree(inp)
foreignPolicy(inp)

print("Country A should work with other nations in global organizations like the UN to end human rights abuses in other nations and find ways to improve affairs in other nations")
print("Agree: Conservative (Isolationist) or Disagree: Liberal (Globalist)")
inp=input()
agreeOrDisagree(inp)
foreignPolicy(inp)

print("Country A, a developed member of the WHO, funds a large part of an organization aimed towards helping developing nations as its country is highly developed and is wealthier")
print("Agree: Liberal (Globalist) or Disagree: Conservative (Isolationist)")
inp=input()
agreeOrDisagree(inp)
foreignPolicy(inp)

print("Country A should help fund the development of underdeveloped nations and global organizations")
print("Agree: Conservative (Isolationist) or Disagree: Liberal (Globalist)")
inp=input()
agreeOrDisagree(inp)
foreignPolicy(inp)

print("Country A, a rich, developed nation, should fund global programs that aim to advance education opportunities in lesser developed nation")
print("Agree: Liberal (Globalist) or Disagree: Conservative (Isolationist)")
inp=input()
agreeOrDisagree(inp)
foreignPolicy(inp)

print("Country A should partake in global organizations like NATO to advance their national security interests and develop allies that would strengthen their influence")
print("Agree: Conservative (isolationist) or Disagree: Liberal (Globalist)")
inp=input()
agreeOrDisagree(inp)
foreignPolicy(inp)

print("Country A  should commit as much funding as possible to advance the development of lesser developed nations, as helping these countries is vastly important")
print("Agree: Liberal (Globalist) or Disagree: Conservative (Isolationist)")
inp=input()
agreeOrDisagree(inp)
foreignPolicy(inp)

print("Scenario: The United States wants to increase revenue, by raising taxes, to fund certain government services that aim to assist the retired and low-income. The government should increase taxes to fund these programs.")
print("Do you strongly agree, agree, neutral, disagree, or strongly disagree")
inp=input()
agreeOrDisagree(inp)
economicPolicy(inp)

print("Scenario: Since Country A is faced with the possibility of many firms going bankrupt in a recession, it’s government should financially assist the firms. Do you strongly agree, agree, neutral, disagree, or strongly disagree")
inp=input()
agreeOrDisagree(inp)
economicPolicy(inp)

print("Scenario: Country A’s government needs to purchase steel. It can either purchase from a cheap foreign supplier or buy from a domestic manufacturer that costs more money. The government should buy it from a domestic manufacturer. Do you strongly agree, agree, neutral, disagree, or strongly disagree")
inp=input()
agreeOrDisagree(inp)
economicPolicy(inp)

print("Scenario: The government is faced with a high unemployment rate in the country and wants to stimulate the economy to reduce the unemployment rate. The government should increase government spending towards unemployment benefits rather than lower taxes to stimulate spending. Do you strongly agree, agree, neutral, disagree, or strongly disagree")
inp=input()
agreeOrDisagree(inp)
economicPolicy(inp)

print("Scenario: Country A’s economy is going through periods of higher than normal inflation. The government should increase taxes rather than reduce spending. Do you strongly agree, agree, neutral, disagree, or strongly disagree")
print("Scenario: Many farmers say that they cannot compete with foreign crops. The government should support these farmers through subsidies and point-of-sale initiatives. Do you strongly agree, agree, neutral, disagree, or strongly disagree")
inp=input()
agreeOrDisagree(inp)
economicPolicy(inp)

print("Scenario: Many workers at companies want to increase the minimum wage to $15, determined to be the minimum living wage. The government should increase the minimum wage. Do you strongly agree, agree, neutral, disagree, or strongly disagree")
inp=input()
agreeOrDisagree(inp)
economicPolicy(inp)

print("Scenario: A manufacturing plant requires its workers to be in a union to be employed. Firms should be allowed to mandate union membership for employment. Do you strongly agree, agree, neutral, disagree, or strongly disagree")
inp=input()
agreeOrDisagree(inp)
economicPolicy(inp)

print("Scenario: Governments in crowded, expensive cities ( like New York) have rent control laws to lower the cost of rent but it can cause shortages. The government should keep rent control laws. Do you strongly agree, agree, neutral, disagree, or strongly disagree")
inp=input()
agreeOrDisagree(inp)
economicPolicy(inp)

print("Scenario: There are many concerns about the solvency of Social Security today and some call for the government to privatize the program, while others feel that the private sector cannot appropriately handle the situation. The government should continue to provide Social Security instead of privatizing it. Do you strongly agree, agree, neutral, disagree, or strongly disagree")
inp=input()
economicPolicy(inp)
agreeOrDisagree(inp)

score=economic+environ+social+foreign
if(score==84):
 print("You are a liberal who mainly believes in issues like abortion rights and seem to strongly side with Democrats on most issues.")
elif (score==42):
 print("You are an independent minded person who does not seem to be swayed by the left nor right. You are a centrist who likes to hear both sides of the situation.")
elif(score>0 and score<42):
 print("You are a right-leaning person who seems to side with Republicans on most issues, but you adopt a more centrist approach compared to conservatives")
elif(score>42  and score<84):
 print("You are a left-leaning Democrat who typically aligns with the Democrats on most issues but are more centrist than some liberals and progressives.")
else:
 print("You are a conservative who seems to strongly vote with Republicans on every issue. You believe in limited government.")


if(economic>=10 and economic <=20):
 print("You seem to believe the rich should pay their fair share of taxes and believe in unions rights and strengthening workers’ rights.")
if(economic<10 and economic>0):
 print("You are more moderate, but you tend to believe in some issues like increasing the pay of minimum wage workers and increasing taxes on the rich, but you do not embrace all of these beliefs")
if(economic==0):e
print("You are not swayed to the right nor to the left. You seem like the person who wants to see a different approach in dealing with the economy")
if(economic>=-20 and economic<=-10):
 print("You seem to be more swayed to the right when it comes to economic policy. You support the free market. You are not the biggest fan of the government but believe it is sometimes necessary for the government to interfere with economics.")
if(economic>-10 and economic<0):
 print("You believe in economic freedom. You do not seem to believe in the government interfering with businesses and not the biggest supporter of labor unions. You believe in promoting competition and keeping your hard earned money for yourself")

if(social<=24 and social>12):
 print("You seem to believe in abortion rights, rights for the LGBTQ+, and reforming immigration to make it more inclusive")
if(social==0):
 print("You may seem to have conservative stances on immigration and/or maybe liberal stances on abortion. Your social policy views tend to be diverse. Not a bad thing!")
if(social >=-24 and social<=-12):
 print("You seem to have right-leaning issues on social policy. You seem to believe in abortion restrictions, protecting our border, and/or opposing the entrance of trans women into women’s sports and promoting religous freedom")
if(social>0 and social<12):
 print("You seem to have left-leaning social policy views. You may believe abortion should be in effect, and the LGBTQ+ community should live their lives. However, you may have some right-leaning stances with other issues like immigration and the war on terrorism")
if(social<0 and social >-12):
 print("You seem to lean to the right on most issues but not too conservative. You may believe in promoting religious tolerance, protecting women’s sports, and securing the border to stop illegals.")

if(environ<=20 and environ>10):
 print("You tend to care alot about the environment and believe the government should take action to protect the environment. You seem to be concerned with the threat of climate change.You believe businesses should be held accountable if they produce pollution.")
if(environ==0):
 print("You have varying views in how we should treat the environment. You may believe certain regulations should stay while other ideas may seem unnecessary and radical.")
if(environ>=-20 and environ<=-10):
 print("You do not consider climate change a serious threat. You do not seem like the person to not support these environmental regulations.")
if(environ>0 and environ<10):
 print("You seem to be more supportive of taking care of the environment. You acknowledge climate change is real and initiatives must be taken.")
if(environ<0 and environ>-10):
 print("You believe humans should take care of the environment but feel the government dealing with these matters is not the best solution and you tend to favor tax incentives and allowing businesses to operate how they want.")

if(foreign<=20 and foreign>=10):
  print("You are more of a globalist. ")
if foreign <=-20 and foreign<=-10:
 print("You have a very right-eaning view in regards to foreign policy. You are skeptical of bringing refugees from different countries. You are considered an isolationist due to your skepticism in meddling in world affairs. You do not seem to be a supporter of sending aid to Ukraine.")
if(foreign>=10 and foreign<0):
 print("You tend to have a more moderate left-leaning foreign policy view. You may support giving aid to Ukraine and funding NATO but may be wary of meddling more in other country’s affairs.")
if(foreign<10 and foreign>0):
 print("You have more of an interventionist foreign policy view. You believe the country should influence other countries to comply with human rights but do not want to get too meddled in country’s affairs..")
if(foreign==0):
  print("You have varying views for foreign policy. You may tend to support giving aid to Ukraine but want to bring all the troops abroad.")


go()



environmental_score = environ / 10 # 10 questions for environmental policy
economic_score = economic / 10  # 10 questions for economic policy
social_score = social / 12  # 12 questions for social policy
foreign_score = foreign / 10  # 10 questions for foreign policy

# Define dimensions and scores
dimensions = ['Environmental', 'Economic', 'Social', 'Foreign']
scores = [environmental_score, economic_score, social_score, foreign_score]
colors = ['blue', 'green', 'red', 'purple']

num_dimensions = len(dimensions)
angles = np.linspace(0, 2 * np.pi, num_dimensions, endpoint=False).tolist()
angles += angles[:1]  # To close the polygon

# Make the plot circular
scores += scores[:1]

# Create a figure and a set of polar axes
fig, ax = plt.subplots(subplot_kw={'polar': True})
for i, color in enumerate(colors):
    ax.fill([angles[i], angles[i+1]], [scores[i], scores[i+1]], color=color, alpha=0.7)


# Set the labels for each dimension
ax.set_xticks(angles[:-1])
ax.set_yticklabels([])
ax.set_xticklabels(dimensions)

# Show the plot
plt.show()
print("This spiderchart represents a visualization of your political ideologies that is categorized into 4 dimenstions: social, economic, environmental, and foreign. A point closer to the center indicates a more conservative view while a point farther from the axis represents a more liberal/progressive view. Overall, this chart should accurately depict your political beliefs in each of the 4 categories")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 718.7/718.7 kB 5.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pyngrok: filename=pyngrok-7.0.0-py3-none-any.whl size=21129 sha256=2f863a0a8392df1097eee463836e7356b23b37fdcbdd145f6f91002fb3fee7eb
#   Stored in directory: /root/.cache/pip/wheels/60/29/7b/f64332aa7e5e88fbd56d4002185ae22dcdc83b35b3d1c2cbf5
# Successfully built pyngrok
# ERROR: Operation cancelled by user
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/pkg_resources/__init__.py", line 3108, in _dep_map
#     return self.__dep_map
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/pkg_resources/__init__.py", line 2901, in __getattr__
#     raise AttributeError(attr)
# AttributeError: _DistInfoDistribution__dep_map
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
# ...
